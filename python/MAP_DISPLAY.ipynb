# %%
import pandas as pd
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 1000,800
from bokeh.models import ColumnDataSource
# %matplotlib notebook

path_to_csv = 'C:/Users/lukas/Documents/fc.csv'

zoom = 14 #change zoom to zoom in
get_last = False
lat, lon = 57.3274, 25.3224

if get_last:
    _df = pd.read_csv(path_to_csv)
    lat, lon = _df['lat'].iloc[-1], _df['long'].iloc[-1]


df = pd.read_csv(path_to_csv)
df.head()
import os 
api_key = 'AIzaSyBzVAZPPiw__1RSfSMxL_1u1hM3rTTJNJc'

from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions


def plot(lat, lng, zoom=zoom, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Cēsu lidlauks', 
             width=bokeh_width, height=bokeh_height)
    # beware, longitude is on the x axis ;-)
    source = ColumnDataSource(df)
    center = p.circle('long', 'lat', size=4, alpha=0.6, color='red', source=source)
    show(p)
    return p

p = plot(lat, lon, map_type='terrain')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="135c9adb-c1ba-471c-823f-434a926f41db" data-root-id="1004"></div>
